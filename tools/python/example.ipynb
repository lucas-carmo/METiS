# %% [markdown]
# # Notebook to illustrate the usage of metisTools

# %%
from metisTools import metis

inputFile  = '../../test/JPK_MOD0_IRR12_180DEG_V00.txt'
outputFile = '../../test/JPK_MOD0_IRR12_180DEG_V00_out.txt'

# %%
mts = metis(inputFile=inputFile, outputFile=outputFile)

mts.view_fowt()
